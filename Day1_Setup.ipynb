# %% [markdown]
# <a href="https://colab.research.google.com/github/shaify-cloud/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain Spanning Tree Protocol'
)
print(resp.text)
# Out:
# The **Spanning Tree Protocol (STP)** is a network protocol that ensures a loop-free logical topology for Ethernet networks. Its primary purpose is to prevent bridge loops and the resulting broadcast storms and MAC table instability that can cripple a network.
#
# ## The Problem STP Solves: Network Loops
#
# In modern networks, redundancy is crucial for reliability. Network engineers often deploy multiple paths between switches so that if one link fails, traffic can still reach its destination. However, redundant physical links in an Ethernet network create a problem: **Layer 2 loops**.
#
# When a loop exists:
#
# 1.  **Broadcast Storms:** Broadcast frames (like ARP requests) will endlessly circle the network, consuming all available bandwidth and eventually causing network devices to become unresponsive.
# ...
